# %% [markdown]
# # Q1. Prepare the dataset
# What is the shape of the downloaded data? How many rows are there?
#
# Answer: 57457

# %%
import pandas as pd
data = pd.read_parquet('data/green_tripdata_2024-03.parquet')
data.shape
# Out:
# (57457, 20)

# %% [markdown]
# # Q2. Metric
# What metric did you choose?
#
# Answer: ColumnSummaryMetric of the trip_distance, which can help understand if there are any negative or zero distances, extreme spikes.

# %% [markdown]
# # Q3. Monitoring
# What is the maximum value of metric quantile = 0.5 on the "fare_amount" column during March 2024 (calculated daily)?
#
# Answer: 14.2

# %% [markdown]
# # Q4. Dashboard
# Where to place a dashboard config file?
#
# Answer: project_folder/dashboards (05-monitoring/dashboards)
